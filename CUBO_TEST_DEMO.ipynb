# %% [markdown]
# <a href="https://colab.research.google.com/github/shijiarui-rs/colab_sjr_rs_w/blob/main/CUBO_TEST_DEMO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-msi
# Out:
# /bin/bash: line 1: nvidia-msi: command not found

# %%
# !nvidia-smi
# Out:
# Tue Jun 25 08:35:38 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !pip install cubo[ee]
# Out:
# Collecting cubo[ee]
#   Downloading cubo-2024.6.0.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: dask>=2023.7.0 in /usr/local/lib/python3.10/dist-packages (from cubo[ee]) (2023.8.1)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from cubo[ee]) (1.25.2)
# Requirement already satisfied: pandas>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from cubo[ee]) (2.0.3)
# Collecting planetary_computer>=1.0.0 (from cubo[ee])
#   Downloading planetary_computer-1.0.0-py3-none-any.whl (14 kB)
# Collecting pystac_client>=0.7.2 (from cubo[ee])
#   Downloading pystac_client-0.8.2-py3-none-any.whl (33 kB)
# Collecting scipy>=1.12.0 (from cubo[ee])
#   Downloading scipy-1.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.1/41.1 MB 15.3 MB/s eta 0:00:00
# Collecting stackstac>=0.4.4 (from cubo[ee])
#   Downloading stackstac-0.5.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: xarray>=2023.6.0 in /usr/local/lib/python3.10/dist-packages (from cubo[ee]) (2023.7.0)
# Collecting xee>=0.0.6 (from cubo[ee])
#   Downloading xee-0.0.14-py3-none-any.whl (30 kB)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.7.0->cubo[ee]) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.7.0->cubo[ee]) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.7.0->cubo[ee]) (2023.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.7.0->cubo[ee]) (24.1)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.7.0->cubo[ee]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.7.0->cubo[ee]) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.7.0->cubo[ee]) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.7.0->cubo[ee]) (7.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.3->cubo[ee]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.3->cubo[ee]) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.3->cubo[ee]) (2024.1)
# Requirement already satisfied: pydantic>=1.7.3 in /usr/local/lib/python3.10/dist-packages (from planetary_computer>=1.0.0->cubo[ee]) (2.7.4)
# Collecting pystac>=1.0.0 (from planetary_computer>=1.0.0->cubo[ee])
#   Downloading pystac-1.10.1-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.9/182.9 kB 27.1 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.25.1 in /usr/local/lib/python3.10/dist-packages (from planetary_computer>=1.0.0->cubo[ee]) (2.31.0)
# Collecting python-dotenv (from planetary_computer>=1.0.0->cubo[ee])
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: pyproj<4.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from stackstac>=0.4.4->cubo[ee]) (3.6.1)
# Collecting rasterio<2.0.0,>=1.3.0 (from stackstac>=0.4.4->cubo[ee])
#   Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 77.4 MB/s eta 0:00:00
# Requirement already satisfied: earthengine-api>=0.1.374 in /usr/local/lib/python3.10/dist-packages (from xee>=0.0.6->cubo[ee]) (0.1.408)
# Collecting affine (from xee>=0.0.6->cubo[ee])
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.10/dist-packages (from earthengine-api>=0.1.374->xee>=0.0.6->cubo[ee]) (2.8.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in /usr/local/lib/python3.10/dist-packages (from earthengine-api>=0.1.374->xee>=0.0.6->cubo[ee]) (2.84.0)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from earthengine-api>=0.1.374->xee>=0.0.6->cubo[ee]) (2.27.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.10/dist-packages (from earthengine-api>=0.1.374->xee>=0.0.6->cubo[ee]) (0.1.1)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from earthengine-api>=0.1.374->xee>=0.0.6->cubo[ee]) (0.22.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask>=2023.7.0->cubo[ee]) (3.19.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.2.0->dask>=2023.7.0->cubo[ee]) (1.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.7.3->planetary_computer>=1.0.0->cubo[ee]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.7.3->planetary_computer>=1.0.0->cubo[ee]) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.7.3->planetary_computer>=1.0.0->cubo[ee]) (4.12.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj<4.0.0,>=3.0.0->stackstac>=0.4.4->cubo[ee]) (2024.6.2)
# Requirement already satisfied: jsonschema~=4.18 in /usr/local/lib/python3.10/dist-packages (from pystac>=1.0.0->planetary_computer>=1.0.0->cubo[ee]) (4.19.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.3->cubo[ee]) (1.16.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio<2.0.0,>=1.3.0->stackstac>=0.4.4->cubo[ee]) (23.2.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio<2.0.0,>=1.3.0->stackstac>=0.4.4->cubo[ee]) (0.7.2)
# Collecting snuggs>=1.4.1 (from rasterio<2.0.0,>=1.3.0->stackstac>=0.4.4->cubo[ee])
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio<2.0.0,>=1.3.0->stackstac>=0.4.4->cubo[ee]) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio<2.0.0,>=1.3.0->stackstac>=0.4.4->cubo[ee]) (67.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.1->planetary_computer>=1.0.0->cubo[ee]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.1->planetary_computer>=1.0.0->cubo[ee]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.1->planetary_computer>=1.0.0->cubo[ee]) (2.0.7)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.374->xee>=0.0.6->cubo[ee]) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.374->xee>=0.0.6->cubo[ee]) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.4.1->earthengine-api>=0.1.374->xee>=0.0.6->cubo[ee]) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.4.1->earthengine-api>=0.1.374->xee>=0.0.6->cubo[ee]) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.4.1->earthengine-api>=0.1.374->xee>=0.0.6->cubo[ee]) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1dev,>=0.9.2->earthengine-api>=0.1.374->xee>=0.0.6->cubo[ee]) (3.1.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema~=4.18->pystac>=1.0.0->planetary_computer>=1.0.0->cubo[ee]) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema~=4.18->pystac>=1.0.0->planetary_computer>=1.0.0->cubo[ee]) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema~=4.18->pystac>=1.0.0->planetary_computer>=1.0.0->cubo[ee]) (0.18.1)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.7.0->cubo[ee]) (14.0.2)
# Collecting lz4>=4.3.2 (from dask>=2023.7.0->cubo[ee])
#   Downloading lz4-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.8 MB/s eta 0:00:00
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage->earthengine-api>=0.1.374->xee>=0.0.6->cubo[ee]) (2.3.3)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage->earthengine-api>=0.1.374->xee>=0.0.6->cubo[ee]) (2.7.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.374->xee>=0.0.6->cubo[ee]) (1.63.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.374->xee>=0.0.6->cubo[ee]) (3.20.3)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api>=0.1.374->xee>=0.0.6->cubo[ee]) (1.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.374->xee>=0.0.6->cubo[ee]) (0.6.0)
# Requirement already satisfied: distributed==2023.8.1 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.7.0->cubo[ee]) (2023.8.1)
# Requirement already satisfied: bokeh>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.7.0->cubo[ee]) (3.3.4)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.10/dist-packages (from dask>=2023.7.0->cubo[ee]) (3.1.4)
# Requirement already satisfied: msgpack>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask>=2023.7.0->cubo[ee]) (1.0.8)
# Requirement already satisfied: psutil>=5.7.2 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask>=2023.7.0->cubo[ee]) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask>=2023.7.0->cubo[ee]) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask>=2023.7.0->cubo[ee]) (3.0.0)
# Requirement already satisfied: tornado>=6.0.4 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask>=2023.7.0->cubo[ee]) (6.3.3)
# Requirement already satisfied: zict>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from distributed==2023.8.1->dask>=2023.7.0->cubo[ee]) (3.0.0)
# Requirement already satisfied: contourpy>=1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->dask>=2023.7.0->cubo[ee]) (1.2.1)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->dask>=2023.7.0->cubo[ee]) (9.4.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->dask>=2023.7.0->cubo[ee]) (2024.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.10.3->dask>=2023.7.0->cubo[ee]) (2.1.5)
# Building wheels for collected packages: cubo
#   Building wheel for cubo (setup.py) ... done
#   Created wheel for cubo: filename=cubo-2024.6.0-py3-none-any.whl size=10194 sha256=f60ea097a51072d12cf9366ceb59873bed9794b5ea4e8fe61e21c70e6882abb8
#   Stored in directory: /root/.cache/pip/wheels/ac/e2/68/c523c157bbb092d8f0727568bcebe09429e7cb182daface08d
# Successfully built cubo
# Installing collected packages: snuggs, scipy, python-dotenv, lz4, affine, rasterio, pystac, stackstac, pystac_client, planetary_computer, xee, cubo
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
# Successfully installed affine-2.4.0 cubo-2024.6.0 lz4-4.3.3 planetary_computer-1.0.0 pystac-1.10.1 pystac_client-0.8.2 python-dotenv-1.0.1 rasterio-1.3.10 scipy-1.14.0 snuggs-1.4.7 stackstac-0.5.0 xee-0.0.14

# %%
import geemap
m = geemap.Map()
m
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=wGOftphm9a1Ztua45rwsn0w6kgHmw-XIxvJVa3pZXlI&tc=J4zpbBLfTwo4jq6S6dgbTSmIzuUY5yG2NHuJnFfy7P0&cc=YrEfH5xadqSxpMop78GarsjtLt0rrKzWCWVBOCRQ7OM
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1ATx3LY5EKOF5gZ3woE1jkw3RP-D4LP35InNISLGj-QPeLHJ3OlVFL5oVCqE
#
# Successfully saved authorization token.
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Mounted at /content/drive

# %%
import cubo
import ee
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
da = cubo.create(
    lat=47.848151988493385,
    lon=13.379491178028564,
    collection="LANDSAT/LC09/C02/T2_L2", # ID of the GEE collection
    bands=["SR_B2","SR_B3","SR_B4"], # Bands to retrieve
    start_date="2021-06-01",
    end_date="2024-06-01", # End date of the cube (remember in GEE this date is not included)
    edge_size=64,
    resolution=10,
    gee=True # Set to True
)
da
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <xarray.DataArray 'LANDSAT/LC09/C02/T2_L2' (time: 13, band: 3, y: 64, x: 64)>
# dask.array<transpose, shape=(13, 3, 64, 64), dtype=float32, chunksize=(13, 1, 64, 64), chunktype=numpy.ndarray>
# Coordinates:
#   * time                       (time) datetime64[ns] 2022-02-02T09:52:03.5060...
#   * x                          (x) float64 3.784e+05 3.785e+05 ... 3.791e+05
#   * y                          (y) float64 5.3e+06 5.3e+06 ... 5.301e+06
#   * band                       (band) object 'SR_B2' 'SR_B3' 'SR_B4'
#     cubo:distance_from_center  (y, x) float64 451.8 444.8 437.9 ... 432.1 439.1
# Attributes:
#     collection:           LANDSAT/LC09/C02/T2_L2
#     stac:                 https://earthengine-stac.storage.googleapis.com/cat...
#     epsg:                 32633
#     resolution:           10
#     edge_size:            64
#     edge_size_m:          640
#     central_lat:          47.848151988493385
#     central_lon:          13.379491178028564
#     central_y:            5300694.38448788
#     central_x:            378764.6058600877
#     time_coverage_start:  2021-06-01
#     time_coverage_end:    2024-06-01
